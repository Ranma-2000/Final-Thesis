# %% [markdown]
# # Stratified KFold+XGBoost+EDA Tutorial
# ### **Hyungsuk Kang, Sungkyunkwan University**
# #### 2017/10/8
# # Outline
# * **1. Introduction**
# * **2. Data preparation**
#     * 2.1 Load data
#     * 2.2 Check for missing values
#     * 2.3 Split features and targets from the data
#     * 2.4 Exploratory Visualization
# * **3. Training/Predicting Pipeline**
#     * 3.1  Define Gini metric
#     * 3.2 Drop Unnecessary Features
#     * 3.3 Stratified KFold
#     * 3.4 XGBoost
# * **4. Prediction and submission**
#     * 4.1 Predict and Submit results

# %% [markdown]
# # **1. Introduction**
#
# This is a full walkthrough for building the machine learning model for Porto Seguro’s Safe Driver Prediction dataset provided by Porto Seguro. Stratified KFold is used due to inbalance of the output variable. XGBoost is used because it is like the winning ticket for classification problem with formatted data. You can check its success on this link. ([XGBoost winning solutions](https://github.com/dmlc/xgboost/tree/master/demo#machine-learning-challenge-winning-solutions)) First, I will prepare the data (driver's information and whether the driver initiated auto insurance or not) then I will focus on prediction.
#
# For more information on XGBoost, click this link.
#
# # [XGBoost](https://xgboost.readthedocs.io/en/latest/)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb

# %% [markdown]
# # **2. Data Preparation**
#
# ## **2.1 Load Data**

# %%
train=pd.read_csv('data/train.csv', na_values=-1)
test=pd.read_csv('data/test.csv', na_values=-1)

# %% [markdown]
# ## 2.2 Check for missing values(NaN)

# %%
train.isnull().values.any()
# Out:
# True

# %% [markdown]
# ### Fill it with median value of the column
#
# this does not harm the distribution of the model

# %% [markdown]
# ## 2.3 Split features and targets from the data

# %%
features = train.drop(['id','target'], axis=1).values
targets = train.target.values

# %% [markdown]
# ## 2.3 Exploratory Visualization
#
# ### Distribution of targets

# %%
ax = sns.countplot(x = targets ,palette="Set2")
sns.set(font_scale=1.5)
ax.set_xlabel(' ')
ax.set_ylabel(' ')
fig = plt.gcf()
fig.set_size_inches(10,5)
ax.set_ylim(top=700000)
for p in ax.patches:
    ax.annotate('{:.2f}%'.format(100*p.get_height()/len(targets)), (p.get_x()+ 0.3, p.get_height()+10000))

plt.title('Distribution of 595212 Targets')
plt.xlabel('Initiation of Auto Insurance Claim Next Year')
plt.ylabel('Frequency [%]')
plt.show()

# %% [markdown]
# ### The plot shows that:
# - the target is imbalanced
# - high bias is expected to 0
# - class weight has to be balanced on training

# %% [markdown]
# ### Correlation matrix

# %%
sns.set(style="white")


# Compute the correlation matrix
corr = train.corr()


# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# ### It can be seen that:
#  - ps\_calc\_\*  features are not related to target at all.
#  - Removing them would prevent the curse of dimensionality.

# %% [markdown]
# # 3. Training/Predicting Pipeline

# %% [markdown]
# ## 3.1 Define Gini Metric

# %%
# Define the gini metric - from https://www.kaggle.com/c/ClaimPredictionChallenge/discussion/703#5897
def gini(actual, pred, cmpcol = 0, sortcol = 1):
    assert( len(actual) == len(pred) )
    all = np.asarray(np.c_[ actual, pred, np.arange(len(actual)) ], dtype=float)
    all = all[ np.lexsort((all[:,2], -1*all[:,1])) ]
    totalLosses = all[:,0].sum()
    giniSum = all[:,0].cumsum().sum() / totalLosses
    
    giniSum -= (len(actual) + 1) / 2.
    return giniSum / len(actual)
 
def gini_normalized(a, p):
    return gini(a, p) / gini(a, a)

def gini_xgb(preds, dtrain):
    labels = dtrain.get_label()
    gini_score = gini_normalized(labels, preds)
    return 'gini', gini_score

# %% [markdown]
# ## 3.2 Drop Unnecessary Columns

# %%
unwanted = train.columns[train.columns.str.startswith('ps_calc_')]

# %%
train = train.drop(unwanted, axis=1)  
test = test.drop(unwanted, axis=1)

# %% [markdown]
# ## 3.3 Stratified KFold
#
# Stratified KFold is used to keep the distribution of each label consistent for each training batch.

# %%
kfold = 5
skf = StratifiedKFold(n_splits=kfold, random_state=42, shuffle=True)

# %% [markdown]
# ## 3.4. XGBoost

# %% [markdown]
# ### Set parameters

# %%
# More parameters has to be tuned. Good luck :)
params = {
    'min_child_weight': 10.0,
    'objective': 'binary:logistic',
    'max_depth': 7,
    'max_delta_step': 1.8,
    'colsample_bytree': 0.4,
    'subsample': 0.8,
    'eta': 0.025,
    'gamma': 0.65,
    'num_boost_round' : 700
    }

# %% [markdown]
# # 4.  Prediction and submission

# %% [markdown]
# ## 4.1. Predict and Submit results

# %% [markdown]
# ### Define X and y

# %%
X = train.drop(['id', 'target'], axis=1).values
y = train.target.values
test_id = test.id.values
test = test.drop('id', axis=1)

# %% [markdown]
# ### Create a submission file
#
# This is a pipeline originated from [StratifiedShuffleSplit + XGBoost example (0.28)](https://www.kaggle.com/kueipo/stratifiedshufflesplit-xgboost-example-0-28)
#
# Original [Simple XGBoost BTB (0.27+)](https://www.kaggle.com/anokas/simple-xgboost-btb-0-27?scriptVersionId=1551232)

# %%
sub = pd.DataFrame()
sub['id'] = test_id
sub['target'] = np.zeros_like(test_id)

# %%
for i, (train_index, test_index) in enumerate(skf.split(X, y)):
    print('[Fold %d/%d]' % (i + 1, kfold))
    X_train, X_valid = X[train_index], X[test_index]
    y_train, y_valid = y[train_index], y[test_index]
    # Convert our data into XGBoost format
    d_train = xgb.DMatrix(X_train, y_train)
    d_valid = xgb.DMatrix(X_valid, y_valid)
    print(X_train.shape, y_train.shape)
    print(type(X_train))
    d_test = xgb.DMatrix(test.values)
    watchlist = [(d_train, 'train'), (d_valid, 'valid')]

    # Train the model! We pass in a max of 1,600 rounds (with early stopping after 70)
    # and the custom metric (maximize=True tells xgb that higher metric is better)
    mdl = xgb.train(params, d_train, 1600, watchlist, early_stopping_rounds=70, custom_metric=gini_xgb, maximize=True, verbose_eval=100)

    print('[Fold %d/%d Prediciton:]' % (i + 1, kfold))
    # Predict on our test data
    print(mdl.best_ntree_limit)
    p_test = mdl.predict(d_test, iteration_range=(0, mdl.best_iteration))
    # p_test = mdl.predict(d_test, ntree_limit=mdl.best_ntree_limit)
    sub['target'] += p_test/kfold
# Out:
# [Fold 1/5]
# (476169, 37) (476169,)
# <class 'numpy.ndarray'>
# C:\Users\DELL\PycharmProjects\Final-Thesis\venv\lib\site-packages\xgboost\core.py:568: FutureWarning: Pass `evals` as keyword args.  Passing these as positional arguments will be considered as error in future releases.
#   warnings.warn(
# [14:15:02] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "num_boost_round" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-logloss:0.67259	train-gini:0.05031	valid-logloss:0.67259	valid-gini:0.06085
# [100]	train-logloss:0.16518	train-gini:0.31798	valid-logloss:0.16600	valid-gini:0.27587
# [200]	train-logloss:0.14966	train-gini:0.35868	valid-logloss:0.15218	valid-gini:0.28400
# [300]	train-logloss:0.14746	train-gini:0.39575	valid-logloss:0.15162	valid-gini:0.28959
# [400]	train-logloss:0.14606	train-gini:0.42362	valid-logloss:0.15153	valid-gini:0.29089
# [495]	train-logloss:0.14492	train-gini:0.44650	valid-logloss:0.15151	valid-gini:0.29067
# [Fold 1/5 Prediciton:]
# 426
# [Fold 2/5]
# (476169, 37) (476169,)
# <class 'numpy.ndarray'>
# [14:17:11] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "num_boost_round" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-logloss:0.67259	train-gini:0.05527	valid-logloss:0.67259	valid-gini:0.03627
# [100]	train-logloss:0.16514	train-gini:0.32198	valid-logloss:0.16610	valid-gini:0.26414
# [200]	train-logloss:0.14956	train-gini:0.36178	valid-logloss:0.15238	valid-gini:0.27608
# [300]	train-logloss:0.14738	train-gini:0.39729	valid-logloss:0.15189	valid-gini:0.28138
# [400]	train-logloss:0.14590	train-gini:0.42643	valid-logloss:0.15181	valid-gini:0.28292
# [500]	train-logloss:0.14479	train-gini:0.44868	valid-logloss:0.15181	valid-gini:0.28353
# [585]	train-logloss:0.14391	train-gini:0.46625	valid-logloss:0.15184	valid-gini:0.28329
# [Fold 2/5 Prediciton:]
# 516
# [Fold 3/5]
# (476170, 37) (476170,)
# <class 'numpy.ndarray'>
# [14:19:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "num_boost_round" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-logloss:0.67258	train-gini:0.04403	valid-logloss:0.67258	valid-gini:0.04009
# [100]	train-logloss:0.16526	train-gini:0.31732	valid-logloss:0.16607	valid-gini:0.26610
# [200]	train-logloss:0.14967	train-gini:0.35914	valid-logloss:0.15224	valid-gini:0.27864
# [300]	train-logloss:0.14742	train-gini:0.39838	valid-logloss:0.15174	valid-gini:0.28335
# [400]	train-logloss:0.14596	train-gini:0.42677	valid-logloss:0.15161	valid-gini:0.28594
# [500]	train-logloss:0.14483	train-gini:0.44869	valid-logloss:0.15160	valid-gini:0.28603
# [552]	train-logloss:0.14433	train-gini:0.45848	valid-logloss:0.15162	valid-gini:0.28558
# [Fold 3/5 Prediciton:]
# 484
# [Fold 4/5]
# (476170, 37) (476170,)
# <class 'numpy.ndarray'>
# [14:22:03] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "num_boost_round" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-logloss:0.67258	train-gini:0.04349	valid-logloss:0.67258	valid-gini:0.03926
# [100]	train-logloss:0.16523	train-gini:0.31550	valid-logloss:0.16608	valid-gini:0.26908
# [200]	train-logloss:0.14959	train-gini:0.36056	valid-logloss:0.15225	valid-gini:0.28116
# [300]	train-logloss:0.14733	train-gini:0.39976	valid-logloss:0.15172	valid-gini:0.28633
# [400]	train-logloss:0.14594	train-gini:0.42714	valid-logloss:0.15167	valid-gini:0.28745
# [444]	train-logloss:0.14540	train-gini:0.43783	valid-logloss:0.15167	valid-gini:0.28731
# [Fold 4/5 Prediciton:]
# 375
# [Fold 5/5]
# (476170, 37) (476170,)
# <class 'numpy.ndarray'>
# [14:23:57] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "num_boost_round" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-logloss:0.67262	train-gini:0.08209	valid-logloss:0.67262	valid-gini:0.08332
# [100]	train-logloss:0.16512	train-gini:0.31885	valid-logloss:0.16624	valid-gini:0.25370
# [200]	train-logloss:0.14946	train-gini:0.36347	valid-logloss:0.15271	valid-gini:0.26561
# [300]	train-logloss:0.14719	train-gini:0.40033	valid-logloss:0.15227	valid-gini:0.27236
# [400]	train-logloss:0.14570	train-gini:0.42987	valid-logloss:0.15222	valid-gini:0.27423
# [418]	train-logloss:0.14546	train-gini:0.43510	valid-logloss:0.15223	valid-gini:0.27428
# [Fold 5/5 Prediciton:]
# 349

# %%
mdl.predict(d_test, iteration_range=(0, mdl.best_iteration))
# Out:
# array([0.02828369, 0.02531623, 0.02482584, ..., 0.02992675, 0.02277192,
#        0.02814503], dtype=float32)

# %% [markdown]
# ### Put submission to csv file

# %%
sub.to_csv('StratifiedKFold.csv', index=False)
